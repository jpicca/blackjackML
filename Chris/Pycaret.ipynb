# %%
import pandas as pd
blackjackdata = pd.read_csv('blackjack_data.csv')
blackjackdata.head()
# Out:
#   d_hand d_final_hand p_hand p_final_hand  strategy  split  num_decks  \
# 0    9,7        9,7,2   10,Q         10,Q         1      0          4
# 1    A,6          A,6    8,3      8,3,5,7         0      0          4
# 2    2,3      2,3,5,K    J,Q          J,Q         0      0          4
# 3    3,Q          3,Q    2,7      2,7,6,9         0      0          4
# 4    4,J      4,J,2,K    3,8        3,8,Q         0      1          4
#
#    soft_17  game_type  d_open  d_initial  d_final  d_hit  d_bust  p_initial  \
# 0        1          0       9         16       18      1       0         20
# 1        0          0       1         17       17      0       0         11
# 2        1          0       2          5       20      1       0         20
# 3        0          0       3         13       13      0       0          9
# 4        1          0       4         14       26      1       1         11
#
#    p_final  p_hit  p_bust  p_win
# 0       20      0       0      1
# ...

# %%
blackjackdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20168 entries, 0 to 20167
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   d_hand        20168 non-null  object
#  1   d_final_hand  20168 non-null  object
#  2   p_hand        20168 non-null  object
#  3   p_final_hand  20168 non-null  object
#  4   strategy      20168 non-null  int64
#  5   split         20168 non-null  int64
#  6   num_decks     20168 non-null  int64
#  7   soft_17       20168 non-null  int64
#  8   game_type     20168 non-null  int64
#  9   d_open        20168 non-null  int64
#  10  d_initial     20168 non-null  int64
#  11  d_final       20168 non-null  int64
#  12  d_hit         20168 non-null  int64
#  13  d_bust        20168 non-null  int64
#  14  p_initial     20168 non-null  int64
#  15  p_final       20168 non-null  int64
#  16  p_hit         20168 non-null  int64
#  17  p_bust        20168 non-null  int64
# ...

# %%
from pycaret.classification import *
clf1 = setup(data = blackjackdata, target = 'p_win')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_f480dd40_97aa_11ea_84b3_a8a795a340b8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f480dd40_97aa_11ea_84b3_a8a795a340b8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f480dd40_97aa_11ea_84b3_a8a795a340b8row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f480dd40_97aa_11ea_84b3_a8a795a340b8row0_col1" class="data row0 col1" >8920</td>
#             </tr>
#             <tr>
#                         <th id="T_f480dd40_97aa_11ea_84b3_a8a795a340b8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f480dd40_97aa_11ea_84b3_a8a795a340b8row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=170)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      14:25:19
# Status     . . . . . . . . . . . . . . . . . .          Fitting Fold 3 of 10
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Discriminant Analysis
# ETC        . . . . . . . . . . . . . . . . . .       38.18 Minutes Remaining
#                              Model  Accuracy     AUC  Recall   Prec.      F1  \
# 0             Ada Boost Classifier    1.0000  1.0000  1.0000  1.0000  1.0000
# 1     Gradient Boosting Classifier    1.0000  1.0000  1.0000  1.0000  1.0000
# 2         Decision Tree Classifier    0.9999  0.9999  1.0000  0.9998  0.9999
# 3           K Neighbors Classifier    0.9846  0.9982  0.9791  0.9835  0.9813
# 4              Logistic Regression    0.9744  0.9975  0.9648  0.9733  0.9690
# 5         Random Forest Classifier    0.9556  0.9923  0.9138  0.9776  0.9446
# ...

# %%
dt = create_model('dt')

# %%
tuned_xgboost = tune_model('xgboost')
